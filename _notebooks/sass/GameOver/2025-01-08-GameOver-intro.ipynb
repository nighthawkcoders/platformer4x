# %% [raw]
# ---
# layout: post
# title: GameOver intro
# description: Understanding the concepts behind GameOver / transitions / and the leaderboard
# permalink: /GameOverHelp/intro
# menu: nav/GameOverHelp.html
# toc: true
# ---

# %% [markdown]
# Explain what your topic is and how it is being used in the game

# %% [markdown]
# Game Over

# %% [markdown]
# Transitions

# %% [markdown]
# Transitions are how the game switches you from your current level to the next level or the selected level if you are using the level select menu
#
# Upon reaching the end of a level you will trigger a function that will update the current level and switch to the next level
#
# ![Screenshot 2025-01-07 133514.png](<attachment:Screenshot 2025-01-07 133514.png>)
#
# In the screenshot below you can see how the function works by removing all the objects on the screen and adds the objects for the next level which is found inside the levels object array
#
# ![Screenshot 2025-01-07 134328.png](<attachment:Screenshot 2025-01-07 134328.png>)

# %% [markdown]
# Leaderboard
